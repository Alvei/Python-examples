# %% [markdown]
# # Python References

# %% [markdown]
# ## General
# [Anaconda](https://docs.anaconda.com/anaconda/user-guide/getting-started/)
#
#
#
# [Python Morsel](https://www.pythonmorsels.com/topics/looping-over-multiple-iterables/)
#
# [List of resources by Python Morsel](https://www.pythonmorsels.com/resources/)
#
# [Practical Business Python Resources](https://pbpython.com/pages/resources.html)
#
# [Full Stack Python](https://www.fullstackpython.com/table-of-contents.html)
#
# [Github list of references](https://gist.github.com/Enteleform/85dc4117c3cac6097495dcd32036a332)
#
# ### Blog
# [Guido's home page](https://gvanrossum.github.io/)
#
# [Neopythonic from Guido](http://neopythonic.blogspot.com/)
#
# [Jake VanderPlas blog](http://jakevdp.github.io/pages/about.html)
#
# [Santiago Blog](https://threadreaderapp.com/thread/1315149223176929280.html)
#
#
# ### Youtube
# [List of youtube Python Channel](https://realpython.com/python-youtube-channels/)
#
# [Real Python youtube](https://www.youtube.com/channel/UCI0vQvr9aFn27yR6Ej6n5UA)

# %% [markdown]
# ## Pandas
#
# [Pandas Reference](https://pandas.pydata.org/community/blog/extension-arrays.html)
#
# [Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/index.html)
#
# [Top 8 resources](http://www.dataschool.io/best-python-pandas-resources/)
#
# [Kaggle Pandas tutorial](https://www.kaggle.com/learn/pandas)
#
# ### Customizing
# [Make DF output ready](https://towardsdatascience.com/make-your-pandas-dataframe-output-report-ready-a9440f6045c6)
#
# [Customizing Jupyter](https://nbviewer.jupyter.org/github/chris1610/pbpython/blob/master/notebooks/Ipython-pandas-tips-and-tricks.ipynb)
#
# [Set background color](https://nbviewer.jupyter.org/github/chris1610/pbpython/blob/master/notebooks/Ipython-pandas-tips-and-tricks.ipynb)
#
# [Jupyter magic command](https://ipython.readthedocs.io/en/stable/interactive/magics.html)
#
# ### Using
#
# [iloc, loc](https://www.shanelynn.ie/select-pandas-dataframe-rows-and-columns-using-iloc-loc-and-ix/)
#
# [Adding row with append()](https://thispointer.com/python-pandas-how-to-add-rows-in-a-dataframe-using-dataframe-append-loc-iloc/)
#
# [Automated Data Engineering](https://towardsdatascience.com/automated-feature-engineering-in-python-99baf11cc219)
#
# [Missing values](https://towardsdatascience.com/working-with-missing-values-in-pandas-5da45d16e74)
#
# [Cleaning dirty data](http://www.developintelligence.com/blog/2017/08/data-cleaning-pandas-python/)
#
# [Summarizing, aggregating and Grouping](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/)
#
# [Grouping and Aggregating](https://pbpython.com/groupby-agg.html)
#
# [Merge and join](https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/)
#
# [Merge 2](https://www.kaggle.com/crawford/python-merge-tutorial/code)
#
# [Guide to Encoding](https://pbpython.com/categorical-encoding.html)
#
# [Common Excel Tasks done in Panda](https://pbpython.com/excel-pandas-comp.html)
#
# [Transform function](http://pbpython.com/pandas_transform.html)
#
# [Multi-Index](https://www.datacamp.com/community/tutorials/pandas-multi-index)
#
# [9 Feature engineering techniques](https://rubikscode.net/2020/11/15/top-9-feature-engineering-techniques/)
#
# ### Ploting
#
# [Plotting got prettier](https://towardsdatascience.com/plotting-in-pandas-just-got-prettier-289d0e0fe5c0)
#
# [Barplot](https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/)
#
# [Understanding df.plot](http://jonathansoma.com/lede/algorithms-2017/classes/fuzziness-matplotlib/understand-df-plot-in-pandas/)
#
# [Matplotlib examples](https://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot)
#
# [5 tips for Pandas users](https://towardsdatascience.com/5-tips-for-pandas-users-e73681d16d17)

# %% [markdown]
# ## Data Structure
# [Dictionary](https://johnlekberg.com/blog/2020-09-19-dict-view.html)
#
# [Dictionaries, maps, hash](https://dbader.org/blog/python-dictionaries-maps-and-hashtables)
#
# [Stack from real python](https://realpython.com/how-to-implement-python-stack/)
#
# [Stack from Dan Blader](https://dbader.org/blog/stacks-in-python)
#
# [Stack implementation](https://runestone.academy/runestone/books/published/pythonds/BasicDS/ImplementingaStackinPython.html)
#
# [Recursive Data Structure](https://composingprograms.com/versions/v1/pages/27-recursive-data-structures.html)

# %% [markdown]
# ## Algo
#
# ## General
#
# [Stanford CS161](http://web.stanford.edu/class/archive/cs/cs161/cs161.1176/#homework)
#
# [MIT intro to algo](https://courses.csail.mit.edu/6.006/fall10/notes.shtml)
#
# [Python algo](http://interactivepython.org/runestone/static/pythonds/index.html)
#
# [OnlineBook-Runestone](https://runestone.academy/runestone/books/published/pythonds/index.html)
#
# [Recursive functions](https://runestone.academy/runestone/books/published/pythonds/BasicDS/ImplementingaStackinPython.html)
#
# [Git repo 1](https://github.com/TheAlgorithms/Python)
#
# [Git repo 2](https://pandas.pydata.org/community/blog/extension-arrays.html)
#
# [Decision Tree](https://towardsdatascience.com/decision-tree-overview-with-no-maths-66b256281e2b#:~:text=Whereas%20in%20a%20linear%20classifier,and%20a%20tree%20is%20built)
#
# [Decision Tree 2](https://www.kaggle.com/dmilla/introduction-to-decision-trees-titanic-dataset#Preparing-the-Titanic-dataset)
#
# ### Max-Flow
# [Ford-Fulkerson 1](https://github.com/odubno/ford-fulkerson-max-flow)
#
# [Ford-Fulkerson using OOP](https://www.geeksforgeeks.org/ford-fulkerson-algorithm-for-maximum-flow-problem/)
#
# [Networkx made easy](https://github.com/ericmjl/Network-Analysis-Made-Simple)
#
# ### Dynamic programing
# [knap-sac 1](https://www.geeksforgeeks.org/knapsack-problem/)

# %% [markdown]
# ## Python built-in function
#
# [100 snippets](https://therenegadecoder.com/code/python-code-snippets-for-everyday-problems/)
#
# [Iterators](https://opensource.com/article/18/3/loop-better-deeper-look-iteration-python)
#
# [User input and error handling](http://hplgit.github.io/primer.html/doc/pub/input/._input-bootstrap007.html)
#
# [Iterator by Trey Hunter](https://treyhunner.com/2018/06/how-to-make-an-iterator-in-python/)
#
# [Lambda, filter, map, reduce](https://www.python-course.eu/lambda.php)
#
# [Filter function](https://www.digitalocean.com/community/tutorials/how-to-use-the-python-filter-function)
#
# [Yield and generators](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/)
#
# [Context manager](https://medium.com/better-programming/context-managers-in-python-go-beyond-with-open-as-file-85a27e392114)
#
# [type() vs. isinstance()](https://switowski.com/blog/type-vs-isinstance)
#
# [try and exception](https://pythonprogramming.net/handling-exceptions-try-except-python-3/?completed=/reading-csv-files-python-3/)
#
# [Assert](https://www.programiz.com/python-programming/assert-statement)
#
# [callable by Trey Hunter](https://treyhunner.com/2019/04/is-it-a-class-or-a-function-its-a-callable/)
#
# [Asterix by Trey Hunter](https://treyhunner.com/2018/10/asterisks-in-python-what-they-are-and-how-to-use-them/)
#
# [f-string](https://medium.com/@NirantK/best-of-python3-6-f-strings-41f9154983e)
#
# [f-string examples](https://miguendes.me/73-examples-to-help-you-master-pythons-f-strings)
#
# [argparse](https://towardsdatascience.com/learn-enough-python-to-be-useful-argparse-e482e1764e05)
#
# [argparse 2](http://zetcode.com/python/argparse/)
#
# [Zip files by coreyS](https://coreyms.com/)

# %% [markdown]
# ## Python Libraries
#
# [Pulp](https://benalexkeen.com/linear-programming-with-python-and-pulp/)
#
# [SQL Alchemy](https://medium.com/hacking-datascience/sqlalchemy-python-tutorial-abcc2ec77b57)
#
# [Five obscure libraries](https://towardsdatascience.com/5-obscure-python-libraries-every-data-scientist-should-know-3651bf5d3be3)
#
# [Under rated libraries](https://fastpages.fast.ai/fastcore/)
#
# [pprint](https://pymotw.com/2/pprint/)
#
# [datetime](http://www.marinamele.com/2014/03/13-useful-tips-about-python-datetime.html)
#
# [dataclass](https://www.codegrepper.com/code-examples/python/dataclass+part+of+standard+library)
#
# [lxml parsing](https://python101.pythonlibrary.org/chapter31_lxml.html)
#
# [YahooFinance](https://github.com/JECSand/yahoofinancials)

# %% [markdown]
# ## Web scraping
# [Guide](https://python-docs.readthedocs.io/en/latest/scenarios/scrape.html)
#
# [PodCast](https://realpython.com/podcasts/rpp/12/)
#
# [Kimberlyfessel Pycon tutorial](http://kimberlyfessel.com/)

# %% [markdown]
# ## Developper environment
#
# [VS with CoreyS](https://www.youtube.com/watch?v=06I63_p-2A4&list=PL-osiE80TeTt66h8cVpmbayBKlMTuS55y&index=8)
#
# [VS code testing example](https://code.visualstudio.com/docs/python/testing)
#
# [Pycon2020](https://us.pycon.org/2020/schedule/presentation/64/)
#
# [Dev tools from Real Python](https://realpython.com/tutorials/tools/)
#
# [Type Checking from Real Python](https://realpython.com/python-type-checking/#duck-types-and-protocols)
#
# [Typing cheatsheet](https://www.pythonsheets.com/notes/python-typing.html)
#
# [State of type hint](https://www.bernat.tech/the-state-of-type-hints-in-python/)
#
# [Structuring projects](https://docs.python-guide.org/writing/structure/)
#
# [Structuring projects 2](https://eugeneyan.com/writing/setting-up-python-project-for-automation-and-collaboration/)
#
# [Style Guidelines](https://luminousmen.com/post/the-ultimate-python-style-guidelines)
#
# [Static analysis](https://luminousmen.com/post/python-static-analysis-tools)
#
# [unit structuring](https://www.patricksoftwareblog.com/python-unit-testing-structuring-your-project/)
#
# [Packaging](https://the-hitchhikers-guide-to-packaging.readthedocs.io/en/latest/)

# %% [markdown]
# ## Testing
# ### References
# [Hitchhiker](https://docs.python-guide.org/writing/tests/)
#
# [Modern test driven dev](https://testdriven.io/blog/modern-tdd/)
#
# [unit test Structuring](https://www.patricksoftwareblog.com/python-unit-testing-structuring-your-project/)
#
# [Unit test example](https://www.journaldev.com/15899/python-unittest-unit-test-example)
#
# [VS code example](https://code.visualstudio.com/docs/python/testing)
#
# [Cheatsheet](https://www.pythonsheets.com/notes/python-tests.html)
#
# [Harry Perceival](https://www.youtube.com/watch?v=rk-f3B-eMkI&feature=youtu.be)
#
# ### Pytest
#
# ### Unittest
# [Module of the week](https://pymotw.com/2/unittest/)
#
# [Documentation](https://pymotw.com/3/unittest/)
#
# [Unittest introduction](https://pythontesting.net/framework/unittest/unittest-introduction/)
#
# [Unittest datacamp repo](https://github.com/gutfeeling/univariate-linear-regression)
