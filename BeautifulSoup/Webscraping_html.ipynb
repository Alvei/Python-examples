# %% [markdown]
# # Webscraping model

# %%
import pandas as pd

# %%
# Scrape data from Wikipedia. In fact, we are going to get the HTML table of Pythonidae snakes (also known as Python snakes).
dfs = pd.read_html('https://en.wikipedia.org/wiki/Pythonidae')
print(f"How many tables on the website {len(dfs)}")
# Out:
# How many tables on the website 8

# %%
# Key table
dfs[2]
# Out:
#        Genus[2]           Taxon author[2]  Species[2]  Subsp.[a][2]  \
# 0     Antaresia  Wells & Wellington, 1984           4             2
# 1   Apodora[13]               Kluge, 1993           1             0
# 2     Aspidites              Peters, 1877           2             0
# 3  Bothrochilus           Fitzinger, 1843           7             0
# 4        Liasis                Gray, 1842           3             5
# 5  Malayopython            Reynolds, 2014           2             3
# 6       Morelia                Gray, 1842           8             6
# 7     Python[b]              Daudin, 1803          10             2
# 8       Simalia                Gray, 1849           7             0
#
#                           Common name  \
# 0                  Children's pythons
# 1                 Papuan olive python
# 2                      Shield pythons
# 3                White-lipped pythons
# 4                       Water pythons
# 5       Reticulated and Timor pythons
# 6                        Tree pythons
# 7                      "True" pythons
# 8  Amethystine python species complex
#
#                                  Geographic range[1]
# 0             Australia in arid and tropical regions
# 1                                   Papua New Guinea
# 2       Australia except in the south of the country
# 3  Most of New Guinea (below 1,200 metres (3,900 ...
# 4  Indonesia in the Lesser Sunda Islands, east th...
# 5                                From India to Timor
# 6  From Indonesia in the Maluku Islands, east thr...
# 7  Africa in the tropics south of the Sahara (not...
# 8  Found in Indonesia (Including the islands of H...

# %% [markdown]
# # Analyze the Sweeden pandemic

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Sweden',
                  match='New COVID-19 cases in Sweden by county')
print(dfs[0].shape)
dfs[0].head()
# Out:
# (155, 37)
#   Source: FOHM[367][a]             County                     \
#                   Date           Blekinge            Dalarna
#                   Date Unnamed: 1_level_2 Unnamed: 2_level_2
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2           2020-02-04                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
#
#                                                                                \
#              Gotland          Gävleborg            Halland           Jämtland
#   Unnamed: 3_level_2 Unnamed: 4_level_2 Unnamed: 5_level_2 Unnamed: 6_level_2
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#                                                             ... Deaths[b]  \
#            Jönköping             Kalmar          Kronoberg  ...     Total
#   Unnamed: 7_level_2 Unnamed: 8_level_2 Unnamed: 9_level_2  ...     Total
# 0                NaN                NaN                NaN  ...       NaN
# 1                NaN                NaN                NaN  ...       NaN
# 2                  1                NaN                NaN  ...       NaN
# 3                NaN                NaN                NaN  ...       NaN
# 4                NaN                NaN                NaN  ...       NaN
#
#               ICU admissions                   Analysed samples[368]        \
#   Diff 7d avg            New Total Diff 7d avg                   New Total
#   Diff 7d avg            New Total Diff 7d avg                   New Total
# 0  NaN    NaN            NaN   NaN  NaN    NaN                    11    11
# 1  NaN    NaN            NaN   NaN  NaN    NaN                    26    37
# 2  NaN    NaN            NaN   NaN  NaN    NaN                    78   115
# 3  NaN    NaN            NaN   NaN  NaN    NaN                    38   153
# 4  NaN    NaN            NaN   NaN  NaN    NaN                    27   180
#
#
#   Week
#   Week
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
#
# [5 rows x 37 columns]

# %%
df = dfs[0].iloc[:-5, :].copy()
df.columns = df.columns.get_level_values(1)
df.columns
# Out:
# Index(['Date', 'Blekinge', 'Dalarna', 'Gotland', 'Gävleborg', 'Halland',
#        'Jämtland', 'Jönköping', 'Kalmar', 'Kronoberg', 'Norrbotten', 'Skåne',
#        'Stockholm', 'Södermanland', 'Uppsala', 'Värmland', 'Västerbotten',
#        'Västernorrland', 'Västmanland', 'Västra Götaland', 'Örebro',
#        'Östergötland', 'New', 'Total', 'Diff', '7d avg', 'New', 'Total',
#        'Diff', '7d avg', 'New', 'Total', 'Diff', '7d avg', 'New', 'Total',
#        'Week'],
#       dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-b9c6864122be> in <module>
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
#
# C:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     726             result = arg.map(cache_array)
#     727         else:
# --> 728             values = convert_listlike(arg._values, format)
#     729             result = arg._constructor(values, index=arg.index, name=arg.name)
#     730     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# C:\Anaconda\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     445             errors=errors,
#     446             require_iso8601=require_iso8601,
# --> 447             allow_object=True,
#     448         )
#     449
#
# C:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1861             return values.view("i8"), tz_parsed
#    1862         except (ValueError, TypeError):
# -> 1863             raise e
#    1864
#    1865     if tz_parsed is not None:
#
# C:\Anaconda\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1852             dayfirst=dayfirst,
#    1853             yearfirst=yearfirst,
# -> 1854             require_iso8601=require_iso8601,
#    1855         )
#    1856     except ValueError as e:
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# C:\Anaconda\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# C:\Anaconda\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ParserError("Unknown string format: %s", timestr)
#     650
#     651         if len(res) == 0:
#
# ParserError: Unknown string format: 2020-03-06[c]

# %%
df.set_index('Date', inplace=True)
